# %%
# ✅ Import libraries
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import torch
import matplotlib.pyplot as plt

# %%
# ✅ Load BLIP processor and model
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base", use_fast=False)
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# %%
# ✅ Load image
image_path = r"C:\Users\Admin\Desktop\VisionVoice\data\sample1.jpg"  # use same image or a different one
raw_image = Image.open(image_path).convert('RGB')

# %%
# ✅ Show the image
plt.imshow(raw_image)
plt.axis('off')
plt.title("Image for Captioning")
plt.show()

# %%
# ✅ Preprocess image and generate caption
inputs = processor(raw_image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("🖼️ Image Caption:")
print(caption)
# Out:
# 🖼️ Image Caption:
# a group of people skate down a street
